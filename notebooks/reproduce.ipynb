# %% [markdown]
# # Cyber Trust by Design — Reproduction Notebook
#
# This notebook reproduces all results from the paper.
#
# **Required:** `pip install -r requirements.txt`

# %%
import sys
sys.path.insert(0, '..')

from src.evaluation import main
main()
